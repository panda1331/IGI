# %%
import pandas as pd

data = pd.read_csv("task6/weatherHistory.csv")
data["Formatted Date"] = pd.to_datetime(data["Formatted Date"], utc=True)

# %%
mask = data["Formatted Date"].dt.hour == 12
filtered_data = data[mask].head(7)
filtered_data.index = filtered_data["Formatted Date"].dt.day_name()

display(filtered_data[["Temperature (C)", "Humidity"]])
# Out:
#                 Temperature (C)  Humidity
# Formatted Date
# Saturday              18.877778      0.47
# Monday                21.050000      0.40
# Tuesday               17.361111      0.71
# Wednesday              9.888889      0.71
# Thursday               9.077778      0.65
# Friday                15.150000      0.50
# Saturday              17.144444      0.43
